# %%
# Imports and setup
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style="whitegrid")

# %%
# Load dataset
df: pd.DataFrame = pd.read_csv("datasets/organizations.csv", index_col=0)

# %%
# Inspect datatset
df.describe(include="all")
# Out:
#         Organization Id         Name             Website Country  \
# count               100          100                 100     100
# unique              100          100                 100      84
# top     FAB0d41d5b5d22c  Ferrell LLC  https://price.net/  Sweden
# freq                  1            1                   1       3
# mean                NaN          NaN                 NaN     NaN
# std                 NaN          NaN                 NaN     NaN
# min                 NaN          NaN                 NaN     NaN
# 25%                 NaN          NaN                 NaN     NaN
# 50%                 NaN          NaN                 NaN     NaN
# 75%                 NaN          NaN                 NaN     NaN
# max                 NaN          NaN                 NaN     NaN
#
#                                 Description      Founded  Industry  \
# count                                   100   100.000000       100
# ...

# %%
df.head(10)
# Out:
#        Organization Id                     Name  \
# Index
# 1      FAB0d41d5b5d22c              Ferrell LLC
# 2      6A7EdDEA9FaDC52  Mckinney, Riley and Day
# 3      0bFED1ADAE4bcC1               Hester Ltd
# 4      2bFC1Be8a4ce42f           Holder-Sellers
# 5      9eE8A6a4Eb96C24              Mayer Group
# 6      cC757116fe1C085           Henry-Thompson
# 7      219233e8aFF1BC3           Hansen-Everett
# 8      ccc93DCF81a31CD            Mcintosh-Mora
# 9      0B4F93aA06ED03e                 Carr Inc
# 10     738b5aDe6B1C6A5               Gaines Inc
#
#                               Website                            Country  \
# Index
# 1                  https://price.net/                   Papua New Guinea
# 2      http://www.hall-buchanan.info/                            Finland
# 3           http://sullivan-reed.com/                              China
# 4                 https://becker.com/                       Turkmenistan
# ...

# %%
# Clean data
df = df.drop_duplicates()
df.head(10)
# Out:
#        Organization Id                     Name  \
# Index
# 1      FAB0d41d5b5d22c              Ferrell LLC
# 2      6A7EdDEA9FaDC52  Mckinney, Riley and Day
# 3      0bFED1ADAE4bcC1               Hester Ltd
# 4      2bFC1Be8a4ce42f           Holder-Sellers
# 5      9eE8A6a4Eb96C24              Mayer Group
# 6      cC757116fe1C085           Henry-Thompson
# 7      219233e8aFF1BC3           Hansen-Everett
# 8      ccc93DCF81a31CD            Mcintosh-Mora
# 9      0B4F93aA06ED03e                 Carr Inc
# 10     738b5aDe6B1C6A5               Gaines Inc
#
#                               Website                            Country  \
# Index
# 1                  https://price.net/                   Papua New Guinea
# 2      http://www.hall-buchanan.info/                            Finland
# 3           http://sullivan-reed.com/                              China
# 4                 https://becker.com/                       Turkmenistan
# ...

# %%
# Top industries
plt.figure(figsize=(8, 4))
top10 = df["Industry"].value_counts().index[:10]
sns.countplot(y="Industry", data=df[df["Industry"].isin(top10)], order=top10)
plt.title("Top 10 Industries by Organization Count")
plt.xlabel("Count")
plt.ylabel("Industry")
plt.show()

# %%
plt.figure(figsize=(8, 4))
sns.histplot(df["Founded"], bins=20, kde=True)
plt.title("Distribution of Founded Years")
plt.xlabel("Year Founded")
plt.ylabel("Number of Organizations")
plt.show()
